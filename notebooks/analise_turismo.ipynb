# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carregar o ficheiro correto
df = pd.read_csv('../data/listings.csv.gz', compression='gzip')

# Visualizar
df.head()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <class 'pandas.DataFrame'>
# RangeIndex: 10731 entries, 0 to 10730
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   N_EXPEDIENT                  10731 non-null  str
#  1   CODI_DISTRICTE               10731 non-null  int64
#  2   NOM_DISTRICTE                10731 non-null  str
#  3   CODI_BARRI                   10725 non-null  float64
#  4   NOM_BARRI                    10725 non-null  str
#  5   TIPUS_CARRER                 10731 non-null  str
#  6   CARRER                       10731 non-null  str
#  7   TIPUS_NUM                    10731 non-null  int64
#  8   NUM1                         10731 non-null  int64
#  9   LLETRA1                      143 non-null    str
#  10  NUM2                         937 non-null    float64
#  11  LLETRA2                      19 non-null     str
# ...
